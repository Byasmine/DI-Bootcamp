# %% [markdown]
# ## Daily Challenge: Classification with Neural Networks in TensorFlow

# %% [markdown]
# ### Understand Classification Types

# %% [markdown]
# * Binary Classification: Two possible outcomes
#
# * Multi-class Classification: More than two classes, but each sample belongs to only one
#
# * Multi-label Classification: Each sample can belong to multiple classes simultaneously

# %% [markdown]
# ### Set Up Environment & Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import make_circles
